# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import sqlite3

DB_FILE_PATH = 'leverage.db'
FPI_TABLE_NAME = 'fpi'

try:
    url = 'https://espn.com/nfl/fpi/_/season/2020'
    page = requests.get(url)
    team_to_posteam = {'Kansas City Chiefs':'KC',
    'Tampa Bay Buccaneers':'TB',
    'New Orleans Saints':'NO',
    'Green Bay Packers':'GB',
    'Baltimore Ravens':'BAL',
    'Buffalo Bills':'BUF',
    'Los Angeles Rams':'LA',
    'Seattle Seahawks':'SEA',
    'Pittsburgh Steelers':'PIT',
    'Tennessee Titans':'TEN',
    'Indianapolis Colts':'IND',
    'San Francisco 49ers':'SF',
    'Arizona Cardinals':'ARI',
    'Atlanta Falcons':'ATL',
    'Minnesota Vikings':'MIN',
    'Cleveland Browns':'CLE',
    'New England Patriots':'NE',
    'Chicago Bears':'CHI',
    'Las Vegas Raiders':'LV',
    'Washington':'WAS',
    'Miami Dolphins':'MIA',
    'Carolina Panthers':'CAR',
    'Houston Texans':'HOU',
    'Denver Broncos':'DEN',
    'Los Angeles Chargers':'LAC',
    'New York Giants':'NYG',
    'Cincinnati Bengals':'CIN',
    'Dallas Cowboys':'DAL',
    'Philadelphia Eagles':'PHI',
    'Detroit Lions':'DET',
    'New York Jets':'NYJ',
    'Jacksonville Jaguars':'JAX'}
    soup = BeautifulSoup(page.text,'html.parser')
    tables = soup.find_all('table')
    teams = [img['alt'] for img in tables[0].find_all('img')]
    table = pd.read_html(str(tables[1]))[0]['POWER INDEX'][['FPI','OFF','DEF','ST']]
    table['team'] = pd.Series(teams).map(team_to_posteam)
    table['created_at'] = datetime.now()
    # TODO: data validations
    print(table)
    conn = sqlite3.connect(DB_FILE_PATH)
    table.to_sql(name=FPI_TABLE_NAME, con=conn, if_exists='append', index=False)
    conn.close()
except Exception as e:
    # TODO: set up emailing in case of exception (once this is a cronjob)
    print(e)
# Out:
#      FPI   OFF  DEF   ST team                 created_at
# 0    9.4  10.0 -0.5 -0.1   KC 2021-08-07 17:00:58.041339
# 1    8.7   5.1  4.1 -0.5   TB 2021-08-07 17:00:58.041339
# 2    7.9   4.5  3.3  0.2   NO 2021-08-07 17:00:58.041339
# 3    7.4   8.4 -0.4 -0.6   GB 2021-08-07 17:00:58.041339
# 4    7.1   3.6  3.1  0.4  BAL 2021-08-07 17:00:58.041339
# 5    5.6   4.7  0.9  0.1  BUF 2021-08-07 17:00:58.041339
# 6    4.7  -0.9  6.0 -0.3   LA 2021-08-07 17:00:58.041339
# 7    4.6   4.4 -0.1  0.3  SEA 2021-08-07 17:00:58.041339
# 8    3.5  -1.8  5.5 -0.2  PIT 2021-08-07 17:00:58.041339
# 9    1.7   5.1 -3.5  0.1  TEN 2021-08-07 17:00:58.041339
# 10   1.6   0.5  1.1  0.0  IND 2021-08-07 17:00:58.041339
# 11   1.2  -1.5  2.7 -0.0   SF 2021-08-07 17:00:58.041339
# 12   1.1   0.7 -0.1  0.4  ARI 2021-08-07 17:00:58.041339
# 13   0.7   1.5 -1.0  0.3  ATL 2021-08-07 17:00:58.041339
# 14   0.2   2.8 -1.9 -0.7  MIN 2021-08-07 17:00:58.041339
# 15  -0.1   2.6 -2.6 -0.1  CLE 2021-08-07 17:00:58.041339
# 16  -0.4  -1.4  0.3  0.7   NE 2021-08-07 17:00:58.041339
# 17  -1.1  -3.5  2.4  0.0  CHI 2021-08-07 17:00:58.041339
# 18  -1.3   2.8 -4.1 -0.1   LV 2021-08-07 17:00:58.041339
# 19  -1.6  -4.7  3.0  0.1  WAS 2021-08-07 17:00:58.041339
# 20  -1.8  -3.8  1.5  0.6  MIA 2021-08-07 17:00:58.041339
# 21  -2.2  -1.2 -0.6 -0.3  CAR 2021-08-07 17:00:58.041339
# 22  -2.5   2.4 -5.2  0.2  HOU 2021-08-07 17:00:58.041339
# 23  -3.6  -5.9  2.4 -0.1  DEN 2021-08-07 17:00:58.041339
# 24  -3.6  -2.9 -0.0 -0.7  LAC 2021-08-07 17:00:58.041339
# 25  -3.8  -3.4 -0.3 -0.0  NYG 2021-08-07 17:00:58.041339
# 26  -5.0  -2.8 -2.5  0.3  CIN 2021-08-07 17:00:58.041339
# 27  -5.8  -2.8 -2.6 -0.4  DAL 2021-08-07 17:00:58.041339
# 28  -6.2  -6.7  0.8 -0.2  PHI 2021-08-07 17:00:58.041339
# 29  -6.8  -0.5 -6.5  0.1  DET 2021-08-07 17:00:58.041339
# 30  -8.2  -7.6 -1.1  0.4  NYJ 2021-08-07 17:00:58.041339
# 31 -11.5  -7.7 -4.1  0.2  JAX 2021-08-07 17:00:58.041339
